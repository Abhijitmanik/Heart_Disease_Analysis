# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("/content/heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df["HeartDisease"].sum()
# Out:
# 508

# %%
df["HeartDisease"].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df.groupby("Age")["HeartDisease"].sum()
# Out:
# Age
# 28     0
# 29     0
# 30     0
# 31     1
# 32     2
# 33     1
# 34     2
# 35     4
# 36     2
# 37     1
# 38    11
# 39     2
# 40     6
# 41     6
# 42     3
# 43    11
# 44     6
# 45     3
# 46    13
# 47    11
# 48    15
# 49    11
# 50    14
# 51    15
# 52    19
# 53    15
# 54    23
# 55    24
# 56    25
# 57    26
# 58    28
# 59    23
# 60    24
# 61    26
# 62    25
# 63    23
# 64    15
# 65    15
# 66     7
# 67    12
# 68     6
# 69    10
# 70     6
# 71     2
# 72     3
# 73     1
# 74     5
# 75     2
# 76     1
# 77     2
# Name: HeartDisease, dtype: int64

# %%
df.groupby("Age")["HeartDisease"].sum().idxmax()
# Out:
# 58

# %%
df.groupby("Age")["HeartDisease"].sum().idxmin()
# Out:
# 28

# %%
sns.displot(df["Age"],kde = True)

# %%
sns.distplot(df["Age"], kde = False , hist = True)
# Out:
# <ipython-input-28-894eb8ca8739>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], kde = False , hist = True)
# <Axes: xlabel='Age'>

# %%
sns.distplot(df["Age"], kde = True, hist = True, rug = True)
# Out:
# <ipython-input-35-faad77e30a63>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], kde = True, hist = True, rug = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Age"], bins = 5)
# Out:
# <ipython-input-37-1512c9bfcc34>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], bins = 5)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["RestingBP"], kde=True, color='blue')
# Out:
# <ipython-input-46-49c51c605c9d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["RestingBP"], kde=True, color='blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df["Cholesterol"], kde = True)
# Out:
# <ipython-input-50-817b30a791c3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cholesterol"], kde = True)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df["FastingBS"], kde = True, color = 'red')
# Out:
# <ipython-input-51-0a0150a6a404>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["FastingBS"], kde = True, color = 'red')
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
df.head()
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0  40.0   M           ATA        140          289          0     Normal
# 1  49.0   F           NAP        160          180          0     Normal
# 2  37.0   M           ATA        130          283          0         ST
# 3  48.0   F           ASY        138          214          0     Normal
# 4  54.0   M           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
sns.distplot(df["Oldpeak"], kde = True, color = 'red')
# Out:
# <ipython-input-53-61dd0e3939cc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Oldpeak"], kde = True, color = 'red')
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %%
sns.distplot(df["MaxHR"], kde = True, color = 'red')
# Out:
# <ipython-input-54-3014eea0a10b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["MaxHR"], kde = True, color = 'red')
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
df.groupby('Sex')

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%.1f', title = "ChestPainType")
# Out:
# <Axes: title={'center': 'ChestPainType'}>

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
sns.violinplot(df["Sex"])
# Out:
# <Axes: ylabel='Sex'>

# %%
sns.violinplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(x = df["Sex"],
               y = df["HeartDisease"], hue = df["Oldpeak"])
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
df.head()
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0  40.0   M           ATA        140          289          0     Normal
# 1  49.0   F           NAP        160          180          0     Normal
# 2  37.0   M           ATA        130          283          0         ST
# 3  48.0   F           ASY        138          214          0     Normal
# 4  54.0   M           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
# Check for non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=["number"]).columns

# Print the non-numeric columns
print(f"Non-numeric columns: {non_numeric_cols}")
# Out:
# Non-numeric columns: Index(['Age', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %%
df = df.select_dtypes(include=["number"])

# %%
df.corr()
# Out:
#                    Sex  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Sex           1.000000  -0.005133     0.200092  -0.120076  0.189186 -0.105734
# RestingBP    -0.005133   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol   0.200092   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS    -0.120076   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR         0.189186  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak      -0.105734   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease -0.305445   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Sex              -0.305445
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df = df.select_dtypes(include=["number", "object"])

# %%
sns.jointplot(x = "RestingBP", y = "MaxHR", data = df)

# %%
sns.jointplot(x = "RestingBP", y = "RestingBP", data = df)

# %%
df.head()
# Out:
#    Sex  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0    0        140          289          0    172      0.0             0
# 1    1        160          180          0    156      1.0             1
# 2    0        130          283          0     98      0.0             0
# 3    1        138          214          0    108      1.5             1
# 4    0        150          195          0    122      0.0             0

# %%
sns.jointplot(x = "Cholesterol", y = "RestingBP", data = df)

# %%
sns.jointplot(x = "Cholesterol", y = "HeartDisease", data = df)

# %%
sns.jointplot(x = "Cholesterol", y = "RestingBP", data = df, kind ='hex')

# %%
sns.jointplot(x = "RestingBP", y = "MaxHR", data = df, kind = 'reg')

# %%
sns.jointplot(x = "Cholesterol", y = "FastingBS", data = df, kind ='reg')

# %%
sns.jointplot(x = "Sex", y = "HeartDisease",  data = df, kind = 'reg')

# %%
sns.jointplot(x = "Cholesterol", y = "MaxHR",  data = df, kind = 'reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue ='HeartDisease')

# %%
sns.pairplot(df.head(), hue = 'Sex')
